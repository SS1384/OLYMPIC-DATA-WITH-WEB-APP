# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
athletes =pd.read_csv("athlete_events.csv") 
regions =pd.read_csv("noc_regions.csv")

# %%
athletes.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
regions.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
df = pd.merge(athletes , regions , on= "NOC")
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       region notes
# 0       Basketball Men's Basketball   NaN        China   NaN
# ...

# %%
df.shape
# Out:
# (270767, 17)

# %%
df.duplicated().sum()
# Out:
# np.int64(1385)

# %%
df.drop_duplicates(inplace = True)
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 270762  135569                Andrzej ya   M  29.0   179.0    89.0
# 270763  135570                  Piotr ya   M  27.0   176.0    59.0
# 270764  135570                  Piotr ya   M  27.0   176.0    59.0
# 270765  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 270766  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df.shape
# Out:
# (269382, 17)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9303
# Height     58726
# Weight     61437
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     229619
# region        21
# notes     264347
# dtype: int64

# %%
df["Medal"].unique()
# Out:
# array([nan, 'Gold', 'Bronze', 'Silver'], dtype=object)

# %%
df["Medal"].fillna("No Medal",inplace = True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6968\2990017439.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Medal"].fillna("No Medal",inplace = True)

# %%
df.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9303
# Height     58726
# Weight     61437
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal          0
# region        21
# notes     264347
# dtype: int64

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event     Medal       region notes
# 0       Basketball Men's Basketball  No Medal        China   NaN
# ...

# %%
df["Season"].value_counts()
# Out:
# Season
# Summer    220818
# Winter     48564
# Name: count, dtype: int64

# %%
summer_df = df[df["Season"] =="Summer"]
winter_df = df[df["Season"] =="Winter" ]

# %%
summer_df.head()
# Out:
#     ID                                Name Sex   Age  Height  Weight  \
# 0    1                           A Dijiang   M  24.0   180.0    80.0
# 1    2                            A Lamusi   M  23.0   170.0    60.0
# 2    3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3    4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 26   8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
#
#               Team  NOC        Games  Year  Season         City       Sport  \
# 0            China  CHN  1992 Summer  1992  Summer    Barcelona  Basketball
# 1            China  CHN  2012 Summer  2012  Summer       London        Judo
# 2          Denmark  DEN  1920 Summer  1920  Summer    Antwerpen    Football
# 3   Denmark/Sweden  DEN  1900 Summer  1900  Summer        Paris  Tug-Of-War
# 26     Netherlands  NED  1932 Summer  1932  Summer  Los Angeles   Athletics
#
#                            Event     Medal       region notes
# ...

# %%
winter_df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight         Team  NOC  \
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 5   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
# 7   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
# 8   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0  Netherlands  NED
#
#          Games  Year  Season         City          Sport  \
# 4  1988 Winter  1988  Winter      Calgary  Speed Skating
# 5  1988 Winter  1988  Winter      Calgary  Speed Skating
# 6  1992 Winter  1992  Winter  Albertville  Speed Skating
# 7  1992 Winter  1992  Winter  Albertville  Speed Skating
# 8  1994 Winter  1994  Winter  Lillehammer  Speed Skating
#
#                                 Event     Medal       region notes
# 4    Speed Skating Women's 500 metres  No Medal  Netherlands   NaN
# ...

# %%
summer_df.shape
# Out:
# (220818, 17)

# %%
winter_df.shape
# Out:
# (48564, 17)

# %% [markdown]
# SEASON WISE MEDAL TALLY

# %%
medal_count_summer = summer_df.groupby(["NOC","Medal"]).size().reset_index(name = "count")
medal_count_summer
# Out:
#      NOC     Medal  count
# 0    AFG    Bronze      2
# 1    AFG  No Medal    124
# 2    AHO  No Medal     73
# 3    AHO    Silver      1
# 4    ALB  No Medal     63
# ..   ...       ...    ...
# 579  ZAM    Silver      1
# 580  ZIM    Bronze      1
# 581  ZIM      Gold     17
# 582  ZIM  No Medal    287
# 583  ZIM    Silver      4
#
# [584 rows x 3 columns]

# %%
medal_pivot_summer = medal_count_summer.pivot(index = "NOC" , columns = "Medal" , values = "count").fillna(0)
medal_pivot_summer
# Out:
# Medal  Bronze   Gold  No Medal  Silver
# NOC
# AFG       2.0    0.0     124.0     0.0
# AHO       0.0    0.0      73.0     1.0
# ALB       0.0    0.0      63.0     0.0
# ALG       8.0    5.0     522.0     4.0
# AND       0.0    0.0      53.0     0.0
# ..        ...    ...       ...     ...
# YEM       0.0    0.0      32.0     0.0
# YMD       0.0    0.0       5.0     0.0
# YUG      92.0  130.0    1659.0   161.0
# ZAM       1.0    0.0     181.0     1.0
# ZIM       1.0   17.0     287.0     4.0
#
# [229 rows x 4 columns]

# %%
medal_pivot_summer =medal_pivot_summer.astype(int)
medal_pivot_summer
# Out:
# Medal  Bronze  Gold  No Medal  Silver
# NOC
# AFG         2     0       124       0
# AHO         0     0        73       1
# ALB         0     0        63       0
# ALG         8     5       522       4
# AND         0     0        53       0
# ..        ...   ...       ...     ...
# YEM         0     0        32       0
# YMD         0     0         5       0
# YUG        92   130      1659     161
# ZAM         1     0       181       1
# ZIM         1    17       287       4
#
# [229 rows x 4 columns]

# %%
medal_pivot_summer["Total_Medal"] = medal_pivot_summer[["Bronze","Gold","Silver"]].sum(axis = 1)
medal_pivot_summer
# Out:
# Medal  Bronze  Gold  No Medal  Silver  Total_Medal
# NOC
# AFG         2     0       124       0            2
# AHO         0     0        73       1            1
# ALB         0     0        63       0            0
# ALG         8     5       522       4           17
# AND         0     0        53       0            0
# ..        ...   ...       ...     ...          ...
# YEM         0     0        32       0            0
# YMD         0     0         5       0            0
# YUG        92   130      1659     161          383
# ZAM         1     0       181       1            2
# ZIM         1    17       287       4           22
#
# [229 rows x 5 columns]

# %%
medal_pivot_summer.sort_values(by=["Bronze","Gold","Silver"],ascending = False).head(30)
# Out:
# Medal  Bronze  Gold  No Medal  Silver  Total_Medal
# NOC
# USA      1197  2472      9813    1333         5002
# GER       649   592      5747     538         1779
# GBR       620   635      8792     729         1984
# URS       596   832      2559     635         2063
# FRA       587   463      8809     567         1617
# AUS       510   342      5787     452         1304
# ITA       454   518      6724     474         1446
# NED       371   245      4188     302          918
# HUN       363   432      4951     328         1123
# SWE       358   354      4920     396         1108
# CAN       344   158      6066     239          741
# JPN       333   230      5466     287          850
# RUS       331   296      2678     278          905
# ROU       290   161      3079     200          651
# CHN       258   334      3414     317          909
# POL       242   111      4278     185          538
# GDR       227   339      1261     277          843
# ...

# %%
summer_df.head()
# Out:
#     ID                                Name Sex   Age  Height  Weight  \
# 0    1                           A Dijiang   M  24.0   180.0    80.0
# 1    2                            A Lamusi   M  23.0   170.0    60.0
# 2    3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3    4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 26   8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
#
#               Team  NOC        Games  Year  Season         City       Sport  \
# 0            China  CHN  1992 Summer  1992  Summer    Barcelona  Basketball
# 1            China  CHN  2012 Summer  2012  Summer       London        Judo
# 2          Denmark  DEN  1920 Summer  1920  Summer    Antwerpen    Football
# 3   Denmark/Sweden  DEN  1900 Summer  1900  Summer        Paris  Tug-Of-War
# 26     Netherlands  NED  1932 Summer  1932  Summer  Los Angeles   Athletics
#
#                            Event     Medal       region notes
# ...

# %%
summer_df = summer_df.drop_duplicates(subset = ["Team","NOC",	"Games",	"Year",	"Season",	"City",	"Sport",	"Event"])
summer_df.shape
# Out:
# (98657, 17)

# %%
medal_count_summer = summer_df.groupby(["NOC","Medal"]).size().reset_index(name = "count")
medal_count_summer
# Out:
#      NOC     Medal  count
# 0    AFG    Bronze      2
# 1    AFG  No Medal     75
# 2    AHO  No Medal     58
# 3    AHO    Silver      1
# 4    ALB  No Medal     57
# ..   ...       ...    ...
# 568  ZAM    Silver      1
# 569  ZIM    Bronze      1
# 570  ZIM      Gold      3
# 571  ZIM  No Medal    204
# 572  ZIM    Silver      4
#
# [573 rows x 3 columns]

# %%
medal_pivot_summer = medal_count_summer.pivot(index = "NOC" , columns = "Medal" , values = "count").fillna(0)
medal_pivot_summer
# Out:
# Medal  Bronze  Gold  No Medal  Silver
# NOC
# AFG       2.0   0.0      75.0     0.0
# AHO       0.0   0.0      58.0     1.0
# ALB       0.0   0.0      57.0     0.0
# ALG       7.0   4.0     359.0     1.0
# AND       0.0   0.0      45.0     0.0
# ..        ...   ...       ...     ...
# YEM       0.0   0.0      32.0     0.0
# YMD       0.0   0.0       5.0     0.0
# YUG      24.0  19.0     608.0    27.0
# ZAM       1.0   0.0     137.0     1.0
# ZIM       1.0   3.0     204.0     4.0
#
# [229 rows x 4 columns]

# %%
medal_pivot_summer =medal_pivot_summer.astype(int)
medal_pivot_summer
# Out:
# Medal  Bronze  Gold  No Medal  Silver
# NOC
# AFG         2     0        75       0
# AHO         0     0        58       1
# ALB         0     0        57       0
# ALG         7     4       359       1
# AND         0     0        45       0
# ..        ...   ...       ...     ...
# YEM         0     0        32       0
# YMD         0     0         5       0
# YUG        24    19       608      27
# ZAM         1     0       137       1
# ZIM         1     3       204       4
#
# [229 rows x 4 columns]

# %%
medal_pivot_summer["Total_Medal"] = medal_pivot_summer[["Bronze","Gold","Silver"]].sum(axis = 1)
medal_pivot_summer
# Out:
# Medal  Bronze  Gold  No Medal  Silver  Total_Medal
# NOC
# AFG         2     0        75       0            2
# AHO         0     0        58       1            1
# ALB         0     0        57       0            0
# ALG         7     4       359       1           12
# AND         0     0        45       0            0
# ..        ...   ...       ...     ...          ...
# YEM         0     0        32       0            0
# YMD         0     0         5       0            0
# YUG        24    19       608      27           70
# ZAM         1     0       137       1            2
# ZIM         1     3       204       4            8
#
# [229 rows x 5 columns]

# %%
medal_pivot_summer.sort_values(by=["Bronze","Gold","Silver"],ascending = False).head(30)
# Out:
# Medal  Bronze  Gold  No Medal  Silver  Total_Medal
# NOC
# USA       371   622      3037     398         1391
# FRA       212   163      3071     166          541
# GER       207   177      2093     186          570
# GBR       202   182      3157     207          591
# URS       179   279       873     206          664
# ITA       157   154      2545     148          459
# AUS       146   109      2479     129          384
# HUN       134   123      2116     118          375
# SWE       126    96      2038     120          342
# CAN       115    51      2610      84          250
# RUS       114   106      1111      99          319
# JPN       113   108      2152      90          311
# POL       111    49      1903      70          230
# CHN        99   161      1311     105          365
# ROU        97    67      1277      75          239
# NED        94    64      1550      81          239
# GDR        90   112       474      74          276
# ...

# %%
winter_df = winter_df.drop_duplicates(subset = ["Team","NOC",	"Games",	"Year",	"Season",	"City",	"Sport",	"Event"])
winter_df.shape
# Out:
# (16956, 17)

# %%
medal_count_winter = winter_df.groupby(["NOC","Medal"]).size().reset_index(name = "count")
medal_count_winter
# Out:
#      NOC     Medal  count
# 0    AHO  No Medal      3
# 1    ALB  No Medal      7
# 2    ALG  No Medal      9
# 3    AND  No Medal     69
# 4    ARG  No Medal    169
# ..   ...       ...    ...
# 222  VEN  No Medal      5
# 223  YUG    Bronze      1
# 224  YUG  No Medal    167
# 225  YUG    Silver      1
# 226  ZIM  No Medal      2
#
# [227 rows x 3 columns]

# %%
medal_pivot_winter = medal_count_winter.pivot(index = "NOC" , columns = "Medal" , values = "count").fillna(0)
medal_pivot_winter
# Out:
# Medal  Bronze  Gold  No Medal  Silver
# NOC
# AHO       0.0   0.0       3.0     0.0
# ALB       0.0   0.0       7.0     0.0
# ALG       0.0   0.0       9.0     0.0
# AND       0.0   0.0      69.0     0.0
# ARG       0.0   0.0     169.0     0.0
# ..        ...   ...       ...     ...
# USA      44.0  39.0     894.0    48.0
# UZB       0.0   1.0      26.0     0.0
# VEN       0.0   0.0       5.0     0.0
# YUG       1.0   0.0     167.0     1.0
# ZIM       0.0   0.0       2.0     0.0
#
# [119 rows x 4 columns]

# %%
medal_pivot_winter =medal_pivot_winter.astype(int)
medal_pivot_winter
# Out:
# Medal  Bronze  Gold  No Medal  Silver
# NOC
# AHO         0     0         3       0
# ALB         0     0         7       0
# ALG         0     0         9       0
# AND         0     0        69       0
# ARG         0     0       169       0
# ..        ...   ...       ...     ...
# USA        44    39       894      48
# UZB         0     1        26       0
# VEN         0     0         5       0
# YUG         1     0       167       1
# ZIM         0     0         2       0
#
# [119 rows x 4 columns]

# %%
medal_pivot_winter["Total_Medal"] = medal_pivot_winter[["Bronze","Gold","Silver"]].sum(axis = 1)
medal_pivot_winter
# Out:
# Medal  Bronze  Gold  No Medal  Silver  Total_Medal
# NOC
# AHO         0     0         3       0            0
# ALB         0     0         7       0            0
# ALG         0     0         9       0            0
# AND         0     0        69       0            0
# ARG         0     0       169       0            0
# ..        ...   ...       ...     ...          ...
# USA        44    39       894      48          131
# UZB         0     1        26       0            1
# VEN         0     0         5       0            0
# YUG         1     0       167       1            2
# ZIM         0     0         2       0            0
#
# [119 rows x 5 columns]

# %%
medal_pivot_winter.sort_values(by=["Bronze","Gold","Silver"],ascending = False).head(30)
# Out:
# Medal  Bronze  Gold  No Medal  Silver  Total_Medal
# NOC
# NOR        48    58       529      43          149
# USA        44    39       894      48          131
# GER        36    39       534      38          113
# SWE        31    23       560      22           76
# SUI        27    18       556      22           67
# FIN        26    15       442      30           71
# CAN        25    43       770      34          102
# ITA        25    19       739      17           61
# FRA        25     8       640      14           47
# URS        24    46       216      24           94
# AUT        24    21       594      31           76
# RUS        21    28       388      22           71
# GDR        19    19       133      17           55
# CHN        12     5       296       8           25
# NED        11    10       202      12           33
# FRG        11     6       209       8           25
# TCH        11     1       285       6           18
# ...

# %% [markdown]
# COUNTRY WISE MEDAL TALLY

# %%
medal_pivot_summer
# Out:
# Medal  Bronze  Gold  No Medal  Silver  Total_Medal
# NOC
# AFG         2     0        75       0            2
# AHO         0     0        58       1            1
# ALB         0     0        57       0            0
# ALG         7     4       359       1           12
# AND         0     0        45       0            0
# ..        ...   ...       ...     ...          ...
# YEM         0     0        32       0            0
# YMD         0     0         5       0            0
# YUG        24    19       608      27           70
# ZAM         1     0       137       1            2
# ZIM         1     3       204       4            8
#
# [229 rows x 5 columns]

# %%
def fetch_noc(noc,pivot_table):
    if noc in pivot_table.index:
        details={
            "Gold":pivot_table.loc[noc,"Gold"],
            "Bronze":pivot_table.loc[noc,"Bronze"],
            "Silver":pivot_table.loc[noc,"Silver"],
            "Total_Medal":pivot_table.loc[noc,"Total_Medal"]
        }
        return details
    else:
        print("NO NOC exists")

# %%
fetch_noc("AFG",medal_pivot_summer)
# Out:
# {'Gold': np.int64(0),
#  'Bronze': np.int64(2),
#  'Silver': np.int64(0),
#  'Total_Medal': np.int64(2)}

# %%
fetch_noc("YUG",medal_pivot_winter)
# Out:
# {'Gold': np.int64(0),
#  'Bronze': np.int64(1),
#  'Silver': np.int64(1),
#  'Total_Medal': np.int64(2)}

# %% [markdown]
# ### Year-Wise

# %%
summer_df
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 0            1                           A Dijiang   M  24.0   180.0    80.0
# 1            2                            A Lamusi   M  23.0   170.0    60.0
# 2            3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 26           8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# ...        ...                                 ...  ..   ...     ...     ...
# 270698  135545                     Henk Jan Zwolle   M  23.0   197.0    93.0
# 270703  135547       Viktoriya Viktorovna Zyabkina   F  19.0   174.0    62.0
# 270738  135556          Bogusaw Stanisaw Zychowicz   M  19.0   189.0    80.0
# 270739  135556          Bogusaw Stanisaw Zychowicz   M  19.0   189.0    80.0
# 270750  135560                   Stavroula Zygouri   F  36.0   171.0    63.0
#
# ...

# %%
summer_df.shape
# Out:
# (98657, 17)

# %%
summer_df.isnull().sum()
# Out:
# ID            0
# Name          0
# Sex           0
# Age        3119
# Height    17827
# Weight    18182
# Team          0
# NOC           0
# Games         0
# Year          0
# Season        0
# City          0
# Sport         0
# Event         0
# Medal         0
# region       20
# notes     96593
# dtype: int64

# %%
summer_df.dropna(subset = ["region"],inplace = True)

# %%
summer_df.isnull().sum()
# Out:
# ID            0
# Name          0
# Sex           0
# Age        3118
# Height    17823
# Weight    18180
# Team          0
# NOC           0
# Games         0
# Year          0
# Season        0
# City          0
# Sport         0
# Event         0
# Medal         0
# region        0
# notes     96593
# dtype: int64

# %%
medals_count = summer_df.groupby(["Year","region","Medal"]).size().unstack(fill_value = 0)

# %%
medals_count
# Out:
# Medal                         Bronze  Gold  No Medal  Silver
# Year region
# 1896 Australia                     1     2         2       0
#      Austria                       2     2         3       1
#      Denmark                       3     1         6       2
#      France                        2     1        11       4
#      Germany                       1     4        21       1
# ...                              ...   ...       ...     ...
# 2016 Virgin Islands, British       0     0         4       0
#      Virgin Islands, US            0     0         7       0
#      Yemen                         0     0         3       0
#      Zambia                        0     0         7       0
#      Zimbabwe                      0     0        13       0
#
# [2769 rows x 4 columns]

# %%
medals_count = medals_count.reset_index()

# %%
medals_count
# Out:
# Medal  index  Year                   region  Bronze  Gold  No Medal  Silver  \
# 0          0  1896                Australia       1     2         2       0
# 1          1  1896                  Austria       2     2         3       1
# 2          2  1896                  Denmark       3     1         6       2
# 3          3  1896                   France       2     1        11       4
# 4          4  1896                  Germany       1     4        21       1
# ...      ...   ...                      ...     ...   ...       ...     ...
# 2764    2764  2016  Virgin Islands, British       0     0         4       0
# 2765    2765  2016       Virgin Islands, US       0     0         7       0
# 2766    2766  2016                    Yemen       0     0         3       0
# 2767    2767  2016                   Zambia       0     0         7       0
# 2768    2768  2016                 Zimbabwe       0     0        13       0
#
# Medal  Total_Medals
# 0                 3
# ...

# %%
medals_count["Total_Medals"] = medals_count["Gold"] + medals_count["Bronze"] + medals_count["Silver"]

# %%
medals_count
# Out:
# Medal  index  Year                   region  Bronze  Gold  No Medal  Silver  \
# 0          0  1896                Australia       1     2         2       0
# 1          1  1896                  Austria       2     2         3       1
# 2          2  1896                  Denmark       3     1         6       2
# 3          3  1896                   France       2     1        11       4
# 4          4  1896                  Germany       1     4        21       1
# ...      ...   ...                      ...     ...   ...       ...     ...
# 2764    2764  2016  Virgin Islands, British       0     0         4       0
# 2765    2765  2016       Virgin Islands, US       0     0         7       0
# 2766    2766  2016                    Yemen       0     0         3       0
# 2767    2767  2016                   Zambia       0     0         7       0
# 2768    2768  2016                 Zimbabwe       0     0        13       0
#
# Medal  Total_Medals
# 0                 3
# ...

# %%
def plot_medals(year,country,df):
    filtered_df = df[(df["Year"] == year) & (df["region"] == country)]
    if filtered_df.empty:
        print(f"No Olympic data found for {country} in {year}.")
        return
    gold = filtered_df["Gold"].values[0]
    bronze = filtered_df["Bronze"].values[0]
    silver = filtered_df["Silver"].values[0]
    total_medals = filtered_df["Total_Medals"].values[0]

    fig,ax = plt.subplots()
    medals = ["Bronze","Gold","Silver","Total_Medals"]
    counts = [bronze,gold,silver,total_medals]
    ax.bar(medals,counts,color = ["g","b","brown" , "yellow"])
    plt.show()

# %%
plot_medals(1896,"Australia",medals_count)

# %% [markdown]
# ###Year wise progress

# %%
medals_count
# Out:
# Medal  index  Year                   region  Bronze  Gold  No Medal  Silver  \
# 0          0  1896                Australia       1     2         2       0
# 1          1  1896                  Austria       2     2         3       1
# 2          2  1896                  Denmark       3     1         6       2
# 3          3  1896                   France       2     1        11       4
# 4          4  1896                  Germany       1     4        21       1
# ...      ...   ...                      ...     ...   ...       ...     ...
# 2764    2764  2016  Virgin Islands, British       0     0         4       0
# 2765    2765  2016       Virgin Islands, US       0     0         7       0
# 2766    2766  2016                    Yemen       0     0         3       0
# 2767    2767  2016                   Zambia       0     0         7       0
# 2768    2768  2016                 Zimbabwe       0     0        13       0
#
# Medal  Total_Medals
# 0                 3
# ...

# %%
def plot_year_progress(country,df):
    filtered_df = df[df["region"]==country]
    fig,ax = plt.subplots()
    ax.plot(filtered_df["Year"],filtered_df["Gold"],color="gold",label = "GOLD",marker="o",linestyle = "-")
    ax.plot(filtered_df["Year"],filtered_df["Bronze"],color="brown",label = "BRONZE",marker="o",linestyle = "-")
    ax.plot(filtered_df["Year"],filtered_df["Silver"],color="silver",label = "SILVER",marker="o",linestyle = "-")
    ax.plot(filtered_df["Year"],filtered_df["Total_Medals"],color="black",label = "TOTAL MEDALS",marker="o",linestyle = "-")
    ax.legend()
    plt.show()

# %%
plot_year_progress("Australia",medals_count)
